# %%
from PIL import Image

def extract_image_info(image_path):
    # Open the image using Pillow
    img = Image.open(image_path)

    # Get image size (in pixels)
    width, height = img.size
    print(f"Image Resolution: {width} x {height} pixels")

    # Get DPI (dots per inch) if available in image metadata (may not always be available)
    dpi = img.info.get('dpi', None)
    if dpi:
        print(f"Image DPI: {dpi}")
    else:
        print("DPI not available in the image metadata.")
    
    return width, height, dpi

# Example usage
image_path = "path_to_your_image.png"
extract_image_info(image_path)
